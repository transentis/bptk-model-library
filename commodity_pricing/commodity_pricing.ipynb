# %% [markdown]
# # Commodity Pricing

# %%
# %%javascript
# /*this sets the title of the browser tab - useful if you have multiple JupyterLab sessions*/
# document.title='BPTK-Py Simulation Library'

# %%
## Load the BPTK Package
from BPTK_Py.bptk import bptk 
bptk = bptk()

# %% [markdown]
# ## Pricing Experiments

# %%
bptk.plot_scenarios(
            scenario_managers=["smCommodityPricing"],
            scenarios=["base","marketShock"], 
            equations=["marketShockOn"]
            )

# %%
bptk.plot_scenarios(
            scenario_managers=["smCommodityPricing"],
            scenarios=["marketShock"], 
            equations=["referenceDemand"]
            )

# %%
bptk.plot_scenarios(
            scenario_managers=["smCommodityPricing"],
            scenarios=["base","marketShock"], 
            equations=["demand"]
            )

# %%
bptk.plot_scenarios(
            scenario_managers=["smCommodityPricing"],
            scenarios=["base","marketShock"], 
            equations=['price']
            )
# Out:
# simulation_models/commodity_pricing.stmx
